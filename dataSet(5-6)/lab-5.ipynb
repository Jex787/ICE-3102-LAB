# %%
import pandas as pd
data = {'Name': ['Mitu', 'Shadat', 'Masud', 'Sourov', 'Mahi', 'Sumaiya'],
        'Age': [23, 23, 24, 22, 22, 20],
        'Gender': ['F', 'M', 'M', 'M', 'F', 'F'],
        'Marks': [80, 83, 'NaN', 90, 92, 'NaN']
       }
df = pd.DataFrame(data)
df
# Out:
#       Name  Age Gender Marks
# 0     Mitu   23      F    80
# 1   Shadat   23      M    83
# 2    Masud   24      M   NaN
# 3   Sourov   22      M    90
# 4     Mahi   22      F    92
# 5  Sumaiya   20      F   NaN

# %%
dataset = pd.read_csv('/kaggle/input/car-driving-risk-analysis/car driving risk analysis.csv')
dataset
# Out:
#     speed  risk
# 0     200    95
# 1      90    20
# 2     300    98
# 3     110    60
# 4     240    72
# 5     115    10
# 6      50     7
# 7     230    85
# 8     190    45
# 9     260    91
# 10    290    82
# 11    185    59
# 12    310    93
# 13     95    18
# 14     30     2

# %%
import statistics as st
# import pandas as pd //if you want
df = pd.read_csv('/kaggle/input/car-driving-risk-analysis/car driving risk analysis.csv')
# print values
print("Mean: ", st.mean(df['speed']))
print("Median: ", st.median(df['speed']))
print("Mode: ", st.mode(df['speed']))
print("Standerd Deviation: ", st.stdev(df['speed']))
print("Variance: ", st.variance(df['speed']))
# Out:
# Mean:  179.66666666666666
# Median:  190
# Mode:  200
# Standerd Deviation:  92.68739062543719
# Variance:  8590.952380952382
